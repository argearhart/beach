# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os

usstations = pd.read_excel('usstations.xlsx')
beach = pd.read_excel('beach_filtered_data.xlsx')
global_sea_levels = pd.read_excel('gmsl.xlsx')

# %%
usstations
# Out:
#      Station ID          Station Name First Year  Last Year  Year Range  \
# 0       1611400        Nawiliwili, HI 1955-01-01 2023-01-01          69
# 1       1612340          Honolulu, HI 1905-01-01 2023-01-01         119
# 2       1612480          Mokuoloe, HI 1957-01-01 2023-01-01          67
# 3       1615680           Kahului, HI 1947-01-01 2023-01-01          77
# 4       1617433          Kawaihae, HI 1988-01-01 2023-01-01          36
# ..          ...                   ...        ...        ...         ...
# 140     9497645       Prudhoe Bay, AK 1988-01-01 2023-01-01          36
# 141     9751401     Lime Tree Bay, VI 1977-01-01 2023-01-01          47
# 142     9751639  Charlotte Amalie, VI 1975-01-01 2023-01-01          49
# 143     9755371          San Juan, PR 1962-01-01 2023-01-01          62
# 144     9759110   Magueyes Island, PR 1955-01-01 2023-01-01          69
#
#      Percent Complete  MSL Trends mm per yr  plus minus CI mm yr   \
# ...

# %%
beach
# Out:
#      State                            Location  Year Completed  \
# 0       AL                     Sand Island Bar            1987
# 1       AL                     Sand Island Bar            1988
# 2       AL                         Gulf Shores            2001
# 3       AL                     Sand Island Bar            1988
# 4       AL                      Dauphin Island            2000
# ...    ...                                 ...             ...
# 1552    CA           Cardiff, San Diego County            2021
# 1553    CA  Goleta Beach, Santa Barbara County            2018
# 1554    CA  Goleta Beach, Santa Barbara County            2017
# 1555    CA  Goleta Beach, Santa Barbara County            2010
# 1556    CA        Newport Beach, Orange County            2009
#
#      Primary Funding Source          Justification  Length (ft) Volume (CY)  \
# 0                   Federal          Demonstration         6000     464,000
# ...

# %%
global_sea_levels
# Out:
#            Time   GMSL  GMSL uncertainty  year
# 0    1880-01-15 -183.0              24.2  1880
# 1    1880-02-15 -171.1              24.2  1880
# 2    1880-03-15 -164.3              24.2  1880
# 3    1880-04-15 -158.2              24.2  1880
# 4    1880-05-15 -158.7              24.2  1880
# ...         ...    ...               ...   ...
# 1603 2013-08-15   71.6               8.8  2013
# 1604 2013-09-15   68.8               8.8  2013
# 1605 2013-10-15   66.4               8.9  2013
# 1606 2013-11-15   59.7               9.0  2013
# 1607 2013-12-15   58.5               9.0  2013
#
# [1608 rows x 4 columns]
